# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.utils.random import sample_without_replacement

# %%
train_data = np.load("./train_base.npz")

# %%
X_train = train_data["data"]
y_train = train_data["targets"]

# %%
#Cross Validation
KNN = KNeighborsClassifier(n_neighbors=10)
cross_val_score(KNN, X_train, y_train, cv=10)
# Out:
# array([0.96716667, 0.9705    , 0.97266667, 0.9675    , 0.966     ,
#        0.97283333, 0.96083333, 0.9695    , 0.9655    , 0.9655    ])

# %%
#Grid Search
parameters = {"n_neighbors":[1,3,5,7,10], "weights":("uniform","distance")}
clf = GridSearchCV( KNeighborsClassifier(), parameters, cv=3 )

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 10],
#                          'weights': ('uniform', 'distance')})

# %%
cv_results = pd.DataFrame(clf.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.186366      0.150014         4.557515        0.115721
# 1       0.167656      0.007845         4.646178        0.051587
# 2       0.082381      0.018652         4.872846        0.408615
# 3       0.155495      0.046031         4.627106        0.086338
# 4       0.075937      0.036884         4.590590        0.092269
# 5       0.151202      0.061104         5.071986        0.368383
# 6       0.257581      0.062755         5.517101        0.118866
# 7       0.180514      0.039423         4.907107        0.190722
# 8       0.069957      0.021892         4.659718        0.101651
# 9       0.049370      0.001583         4.610980        0.034292
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  3       uniform
# 3                  3      distance
# 4                  5       uniform
# 5                  5      distance
# 6                  7       uniform
# 7                  7      distance
# 8                 10       uniform
# 9                 10      distance
#
#                                        params  split0_test_score  \
# 0    {'n_neighbors': 1, 'weights': 'uniform'}            0.96995
# 1   {'n_neighbors': 1, 'weights': 'distance'}            0.96995
# 2    {'n_neighbors': 3, 'weights': 'uniform'}            0.97100
# 3   {'n_neighbors': 3, 'weights': 'distance'}            0.97220
# 4    {'n_neighbors': 5, 'weights': 'uniform'}            0.96960
# 5   {'n_neighbors': 5, 'weights': 'distance'}            0.97120
# 6    {'n_neighbors': 7, 'weights': 'uniform'}            0.96760
# 7   {'n_neighbors': 7, 'weights': 'distance'}            0.96885
# 8   {'n_neighbors': 10, 'weights': 'uniform'}            0.96505
# 9  {'n_neighbors': 10, 'weights': 'distance'}            0.96800
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.96850            0.96615         0.968200        0.001566
# 1            0.96850            0.96615         0.968200        0.001566
# 2            0.96860            0.96730         0.968967        0.001533
# 3            0.97010            0.96790         0.970067        0.001756
# 4            0.96770            0.96705         0.968117        0.001082
# 5            0.96935            0.96830         0.969617        0.001199
# 6            0.96655            0.96460         0.966250        0.001243
# 7            0.96770            0.96610         0.967550        0.001128
# 8            0.96450            0.96380         0.964450        0.000512
# 9            0.96700            0.96575         0.966917        0.000920
#
#    rank_test_score
# 0                4
# 1                4
# 2                3
# 3                1
# 4                6
# 5                2
# 6                9
# 7                7
# 8               10
# 9                8

# %%
clf.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
cv_test_score = max(cv_results["mean_test_score"])
cv_test_score*100
# Out:
# 97.00666666666665

# %% [markdown]
# # KNN on augmented data

# %%
train_data = np.load("./train_aug.npz")
X_train = train_data["data"]
y_train = train_data["targets"]

# %%
idxs = sample_without_replacement( X_train.shape[0], 60000)
X_train = X_train[idxs]
y_train = y_train[idxs]

# %%
#Cross Validation
KNN = KNeighborsClassifier(n_neighbors=10)
cross_val_score(KNN, X_train, y_train, cv=5)
# Out:
# array([0.96925   , 0.96425   , 0.96833333, 0.9645    , 0.96308333])

# %%
#Grid Search
parameters = {"n_neighbors":[1,3,5,7,10], "weights":("uniform","distance")}
clf = GridSearchCV( KNeighborsClassifier(), parameters, cv=3 )

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 10],
#                          'weights': ('uniform', 'distance')})

# %%
cv_results = pd.DataFrame(clf.cv_results_)
cv_test_score = max(cv_results["mean_test_score"])
cv_test_score*100
# Out:
# 97.18

# %%
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.244054      0.122765        10.221014        2.570370
# 1       0.424208      0.159432        13.321423        0.760568
# 2       0.227543      0.110522        11.026658        0.303680
# 3       0.169726      0.036248        10.411677        0.157113
# 4       0.216224      0.105784        10.789688        0.132063
# 5       0.264488      0.119505        10.774188        0.571404
# 6       0.144962      0.020863        10.886639        0.212549
# 7       0.386164      0.060057        12.375182        0.841636
# 8       0.296119      0.128426        10.977389        0.498360
# 9       0.365533      0.134849        25.909632       22.302752
#
#    param_n_neighbors param_weights  \
# 0                  1       uniform
# 1                  1      distance
# 2                  3       uniform
# 3                  3      distance
# 4                  5       uniform
# 5                  5      distance
# 6                  7       uniform
# 7                  7      distance
# 8                 10       uniform
# 9                 10      distance
#
#                                        params  split0_test_score  \
# 0    {'n_neighbors': 1, 'weights': 'uniform'}            0.97195
# 1   {'n_neighbors': 1, 'weights': 'distance'}            0.97195
# 2    {'n_neighbors': 3, 'weights': 'uniform'}            0.96945
# 3   {'n_neighbors': 3, 'weights': 'distance'}            0.97085
# 4    {'n_neighbors': 5, 'weights': 'uniform'}            0.96775
# 5   {'n_neighbors': 5, 'weights': 'distance'}            0.96970
# 6    {'n_neighbors': 7, 'weights': 'uniform'}            0.96620
# 7   {'n_neighbors': 7, 'weights': 'distance'}            0.96770
# 8   {'n_neighbors': 10, 'weights': 'uniform'}            0.96365
# 9  {'n_neighbors': 10, 'weights': 'distance'}            0.96670
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.97330            0.97015         0.971800        0.001290
# 1            0.97330            0.97015         0.971800        0.001290
# 2            0.96995            0.96890         0.969433        0.000429
# 3            0.97160            0.97095         0.971133        0.000332
# 4            0.96915            0.96585         0.967583        0.001352
# 5            0.97075            0.96785         0.969433        0.001199
# 6            0.96755            0.96430         0.966017        0.001333
# 7            0.96975            0.96580         0.967750        0.001613
# 8            0.96395            0.96080         0.962800        0.001420
# 9            0.96700            0.96340         0.965700        0.001631
#
#    rank_test_score
# 0                1
# 1                1
# 2                4
# 3                3
# 4                7
# 5                4
# 6                8
# 7                6
# 8               10
# 9                9
